# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.image as plting 
import pydotplus

# %%
#importing dataset
df=pd.read_csv("Crop_recommendation2.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph  season soil texture  \
# 0      90  42  43    20.879744  82.002744  6.502985  kharif         clay
# 1      85  58  41    21.770462  80.319644  7.038096  kharif         clay
# 2      60  55  44    23.004459  82.320763  7.840207  kharif         clay
# 3      74  35  40    26.491096  80.158363  6.980401  kharif         clay
# 4      78  42  42    20.130175  81.604873  7.628473  kharif         clay
# ...   ...  ..  ..          ...        ...       ...     ...          ...
# 2195  107  34  32    26.774637  66.413269  6.780064    rabi        sandy
# 2196   99  15  27    27.417112  56.636362  6.086922    rabi        sandy
# 2197  118  33  30    24.131797  67.225123  6.362608    rabi        sandy
# 2198  117  32  34    26.272418  52.127394  6.758793    rabi        sandy
# 2199  104  18  30    23.603016  60.396475  6.779833    rabi        sandy
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
#STRING OPERATIONS

# %%
#SELECTING A SINGLE COLUMN
df["label"]
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
#SLICING OPERATION
df2=df[0:10]
df2
# Out:
#     N   P   K  temperature   humidity        ph  season soil texture  \
# 0  90  42  43    20.879744  82.002744  6.502985  kharif         clay
# 1  85  58  41    21.770462  80.319644  7.038096  kharif         clay
# 2  60  55  44    23.004459  82.320763  7.840207  kharif         clay
# 3  74  35  40    26.491096  80.158363  6.980401  kharif         clay
# 4  78  42  42    20.130175  81.604873  7.628473  kharif         clay
# 5  69  37  42    23.058049  83.370118  7.073454  kharif         clay
# 6  69  55  38    22.708838  82.639414  5.700806  kharif         clay
# 7  94  53  40    20.277744  82.894086  5.718627  kharif         clay
# 8  89  54  38    24.515881  83.535216  6.685346  kharif         clay
# 9  68  58  38    23.223974  83.033227  6.336254  kharif         clay
#
#      rainfall label
# 0  202.935536  rice
# 1  226.655537  rice
# 2  263.964248  rice
# 3  242.864034  rice
# 4  262.717340  rice
# 5  251.055000  rice
# 6  271.324860  rice
# 7  241.974195  rice
# ...

# %%
#SORTING
df.sort_index(axis=1)
# Out:
#        K    N   P   humidity   label        ph    rainfall  season  \
# 0     43   90  42  82.002744    rice  6.502985  202.935536  kharif
# 1     41   85  58  80.319644    rice  7.038096  226.655537  kharif
# 2     44   60  55  82.320763    rice  7.840207  263.964248  kharif
# 3     40   74  35  80.158363    rice  6.980401  242.864034  kharif
# 4     42   78  42  81.604873    rice  7.628473  262.717340  kharif
# ...   ..  ...  ..        ...     ...       ...         ...     ...
# 2195  32  107  34  66.413269  coffee  6.780064  177.774507    rabi
# 2196  27   99  15  56.636362  coffee  6.086922  127.924610    rabi
# 2197  30  118  33  67.225123  coffee  6.362608  173.322839    rabi
# 2198  34  117  32  52.127394  coffee  6.758793  127.175293    rabi
# 2199  30  104  18  60.396475  coffee  6.779833  140.937041    rabi
#
#      soil texture  temperature
# 0            clay    20.879744
# 1            clay    21.770462
# 2            clay    23.004459
# 3            clay    26.491096
# ...

# %%
#RESULT ON CONDITION BASIS
df[df.humidity>97.5]
# Out:
#        N   P   K  temperature   humidity        ph season soil texture  \
# 1804  10  18  35    27.797977  99.645730  6.381975   zaid        sandy
# 1809  25   7  35    28.385039  99.188437  5.557712   zaid        sandy
# 1813  37  18  30    27.635513  99.348549  6.384884   zaid        sandy
# 1814  19  15  34    26.296449  99.658092  5.685889   zaid        sandy
# 1816  31  20  26    25.565678  97.613615  6.443169   zaid        sandy
# 1837  32  12  30    25.392411  98.089512  5.579845   zaid        sandy
# 1838  30  25  31    26.312706  98.620480  5.804965   zaid        sandy
# 1841  40   5  29    28.484449  97.768655  5.820979   zaid        sandy
# 1846  32  20  35    26.521664  98.382277  5.588655   zaid        sandy
# 1857   0  29  32    28.059124  98.367098  5.868256   zaid        sandy
# 1864   6  13  29    27.311557  99.969060  5.832608   zaid        sandy
# 1865  15  28  32    28.842710  99.643285  6.218572   zaid        sandy
# ...

# %%
#COPY
df1=df.copy()
df1
# Out:
#         N   P   K  temperature   humidity        ph  season soil texture  \
# 0      90  42  43    20.879744  82.002744  6.502985  kharif         clay
# 1      85  58  41    21.770462  80.319644  7.038096  kharif         clay
# 2      60  55  44    23.004459  82.320763  7.840207  kharif         clay
# 3      74  35  40    26.491096  80.158363  6.980401  kharif         clay
# 4      78  42  42    20.130175  81.604873  7.628473  kharif         clay
# ...   ...  ..  ..          ...        ...       ...     ...          ...
# 2195  107  34  32    26.774637  66.413269  6.780064    rabi        sandy
# 2196   99  15  27    27.417112  56.636362  6.086922    rabi        sandy
# 2197  118  33  30    24.131797  67.225123  6.362608    rabi        sandy
# 2198  117  32  34    26.272418  52.127394  6.758793    rabi        sandy
# 2199  104  18  30    23.603016  60.396475  6.779833    rabi        sandy
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
#ADDING NEW COLUMN IN DATA SET
df2.insert(1,"village",["vzm","vizag","eastgd","westgd","tuni","srikakulam","chittor","praksham","nellimarla","gushini"])
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8019928b65c1> in <module>
#       1 #ADDING NEW COLUMN IN DATA SET
# ----> 2 df2.insert(1,"village",["vzm","vizag","eastgd","westgd","tuni","srikakulam","chittor","praksham","nellimarla","gushini"])
#       3 df2
#
# NameError: name 'df2' is not defined

# %%
#DROPPING A COLUMN FROM DATASET
df3=df2.drop("village",axis="columns")
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-01a8c97dd6ea> in <module>
#       1 #DROPPING A COLUMN FROM DATASET
# ----> 2 df3=df2.drop("village",axis="columns")
#       3 df3
#
# NameError: name 'df2' is not defined

# %%
#HEAD:head gives the data from starting to user given ending
df.head(15)
# Out:
#      N   P   K  temperature   humidity        ph  season soil texture  \
# 0   90  42  43    20.879744  82.002744  6.502985  kharif         clay
# 1   85  58  41    21.770462  80.319644  7.038096  kharif         clay
# 2   60  55  44    23.004459  82.320763  7.840207  kharif         clay
# 3   74  35  40    26.491096  80.158363  6.980401  kharif         clay
# 4   78  42  42    20.130175  81.604873  7.628473  kharif         clay
# 5   69  37  42    23.058049  83.370118  7.073454  kharif         clay
# 6   69  55  38    22.708838  82.639414  5.700806  kharif         clay
# 7   94  53  40    20.277744  82.894086  5.718627  kharif         clay
# 8   89  54  38    24.515881  83.535216  6.685346  kharif         clay
# 9   68  58  38    23.223974  83.033227  6.336254  kharif         clay
# 10  91  53  40    26.527235  81.417538  5.386168  kharif         clay
# 11  90  46  42    23.978982  81.450616  7.502834  kharif         clay
# ...

# %%
#SHAPE:shape gives the no.of.columns and rows in dataset
df.shape
# Out:
# (2200, 10)

# %%
#DESCRIBE:describe gives the mathematical information of columns 
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
#DTYPE:dtype gives the data type of columns
df.dtypes
# Out:
# N                 int64
# P                 int64
# K                 int64
# temperature     float64
# humidity        float64
# ph              float64
# season           object
# soil texture     object
# rainfall        float64
# label            object
# dtype: object

# %%
df['soil texture']=df['soil texture'].map({'clay':1,'silt':2,'sandy':3,'loam':4})
df
# Out:
#         N   P   K  temperature   humidity        ph  season  soil texture  \
# 0      90  42  43    20.879744  82.002744  6.502985  kharif             1
# 1      85  58  41    21.770462  80.319644  7.038096  kharif             1
# 2      60  55  44    23.004459  82.320763  7.840207  kharif             1
# 3      74  35  40    26.491096  80.158363  6.980401  kharif             1
# 4      78  42  42    20.130175  81.604873  7.628473  kharif             1
# ...   ...  ..  ..          ...        ...       ...     ...           ...
# 2195  107  34  32    26.774637  66.413269  6.780064    rabi             3
# 2196   99  15  27    27.417112  56.636362  6.086922    rabi             3
# 2197  118  33  30    24.131797  67.225123  6.362608    rabi             3
# 2198  117  32  34    26.272418  52.127394  6.758793    rabi             3
# 2199  104  18  30    23.603016  60.396475  6.779833    rabi             3
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
df['season']=df['season'].map({'kharif':1,'rabi':2,'zaid':3})
df
# Out:
#         N   P   K  temperature   humidity        ph  season  soil texture  \
# 0      90  42  43    20.879744  82.002744  6.502985       1             1
# 1      85  58  41    21.770462  80.319644  7.038096       1             1
# 2      60  55  44    23.004459  82.320763  7.840207       1             1
# 3      74  35  40    26.491096  80.158363  6.980401       1             1
# 4      78  42  42    20.130175  81.604873  7.628473       1             1
# ...   ...  ..  ..          ...        ...       ...     ...           ...
# 2195  107  34  32    26.774637  66.413269  6.780064       2             3
# 2196   99  15  27    27.417112  56.636362  6.086922       2             3
# 2197  118  33  30    24.131797  67.225123  6.362608       2             3
# 2198  117  32  34    26.272418  52.127394  6.758793       2             3
# 2199  104  18  30    23.603016  60.396475  6.779833       2             3
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
df[100:120]
# Out:
#       N   P   K  temperature   humidity        ph  season  soil texture  \
# 100  71  54  16    22.613600  63.690706  5.749914       2             2
# 101  61  44  17    26.100184  71.574769  6.931757       2             2
# 102  80  43  16    23.558821  71.593514  6.657965       2             2
# 103  73  58  21    19.972160  57.682729  6.596061       2             2
# 104  61  38  20    18.478913  62.695039  5.970458       2             2
# 105  68  41  16    21.776893  57.808406  6.158831       2             2
# 106  93  41  17    25.621717  66.504155  6.047907       2             2
# 107  89  60  19    25.191924  66.690290  5.913665       2             2
# 108  76  44  17    20.416831  62.554248  5.855442       2             2
# 109  67  60  25    24.921622  66.786274  5.750255       2             2
# 110  70  44  19    23.316891  73.454154  5.852607       2             2
# 111  90  49  21    24.840167  68.358457  6.472523       2             2
# ...

# %%
df.isna().sum()
# Out:
# N               0
# P               0
# K               0
# temperature     0
# humidity        0
# ph              0
# season          0
# soil texture    0
# rainfall        0
# label           0
# dtype: int64

# %%
#corelation tells about the depdency of variables
corr=df.corr()
corr
# Out:
#                      N         P         K  temperature  humidity        ph  \
# N             1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P            -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K            -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature   0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity      0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph            0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# season       -0.155719 -0.075901  0.088802     0.145940 -0.087227 -0.155723
# soil texture -0.561679  0.083011  0.085355    -0.033483 -0.166590 -0.032004
# rainfall      0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#                 season  soil texture  rainfall
# N            -0.155719     -0.561679  0.059020
# P            -0.075901      0.083011 -0.063839
# K             0.088802      0.085355 -0.053461
# ...

# %%
#import sklearn library for train the model
from sklearn.model_selection import train_test_split

# %%
#from the dataset here we taking inputs as n,p,k,temperature,hunidity,ph,rainfall
x=np.array(df[['N','P','K','temperature','humidity','ph','season','soil texture','rainfall']])

# %%
#output
y=np.array(df[["label"]])

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
x_train,x_test,y_train,y_test=train_test_split(x,y)
model_dt = LogisticRegression()

# %%
model_dt.fit(x_train,y_train)
# Out:
# C:\Users\BINDUPRIYA\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\BINDUPRIYA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.9709090909090909

# %%
#KNEIGHBORSCLASSIFIER
from sklearn.neighbors import KNeighborsClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y)
model_dt = KNeighborsClassifier()

# %%
model_dt.fit(x_train,y_train)
# Out:
# C:\Users\BINDUPRIYA\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.9818181818181818

# %%
#importing trees from sklearn
from sklearn.tree import DecisionTreeClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y)
model_dt = DecisionTreeClassifier()

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#finding the accuracy of test
model_dt.score(x_test,y_test)
# Out:
# 0.9927272727272727

# %%
#finding accuracy of train
model_dt.score(x_train,y_train)
# Out:
# 1.0

# %%
a=float(input("Enter the Nitrogen value="))
b=float(input("Enter the phosphorus vaue="))
c=float(input("Enter the potassium value="))
d=float(input("Enter the Temperatue value="))
e=float(input("Enter the Humidity value="))
f=float(input("Enter the Ph value="))
g=float(input("Enter the Season value="))
h=float(input("Enter the Soil texture value="))
i=float(input("Enter the Rainfall value="))

# %%
data=np.array([[a,b,c,d,e,f,g,h,i]])
model_dt.predict(data)
# Out:
# array(['apple'], dtype=object)

# %%
data=np.array([[94.30,17.34,19.09,31,78,6.9,2,1,588]])
model_dt.predict(data)
# Out:
# array(['maize'], dtype=object)

# %%
df["label"].nunique()
# Out:
# 22

# %%
df["label"].value_counts()
# Out:
# coconut        100
# orange         100
# pigeonpeas     100
# blackgram      100
# rice           100
# maize          100
# cotton         100
# chickpea       100
# apple          100
# lentil         100
# coffee         100
# mungbean       100
# muskmelon      100
# kidneybeans    100
# banana         100
# jute           100
# pomegranate    100
# papaya         100
# mothbeans      100
# mango          100
# watermelon     100
# grapes         100
# Name: label, dtype: int64

# %%
df.max()
# Out:
# N                      140
# P                      145
# K                      205
# temperature      43.675493
# humidity         99.981876
# ph                9.935091
# season                   3
# soil texture             4
# rainfall        298.560117
# label           watermelon
# dtype: object

# %%
df.min()
# Out:
# N                       0
# P                       5
# K                       5
# temperature      8.825675
# humidity         14.25804
# ph               3.504752
# season                  1
# soil texture            1
# rainfall        20.211267
# label               apple
# dtype: object

# %%
df['K'].max()
# Out:
# 205

# %%
data=np.array([[94.30,35,19.09,31,78,6.9,1,1,588]])
model_dt.predict(data)
# Out:
# array(['rice'], dtype=object)
